# %%
pip install topsis-pushkar-manocha-102303751
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement topsis-pushkar-manocha-102303751 (from versions: none)
# ERROR: No matching distribution found for topsis-pushkar-manocha-102303751
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

data = {
    "Model": ["A", "B", "C", "D"],
    "Price": [250, 200, 300, 275],
    "Battery": [8, 6, 9, 7],
    "Camera": [12, 10, 14, 13],
    "Storage": [128, 64, 256, 128]
}

df = pd.DataFrame(data)
df.to_csv("input.csv", index=False)

df
# Out:
#   Model  Price  Battery  Camera  Storage
# 0     A    250        8      12      128
# 1     B    200        6      10       64
# 2     C    300        9      14      256
# 3     D    275        7      13      128

# %%
# !topsis-hk input.csv "1,1,1,1" "-,+,+,+" output.csv
# Out:
# 'topsis-hk' is not recognized as an internal or external command,
# operable program or batch file.

# %%
out = pd.read_csv("output.csv")
out
# Out:
#   Model  Storage  Camera  Price  Rating  Topsis Score (102303751)  \
# 0    M1       16      12    250       5                  0.534277
# 1    M2       16       8    200       3                  0.308368
# 2    M3       32      16    300       4                  0.691632
# 3    M4       32       8    275       4                  0.534737
# 4    M5       16      16    225       2                  0.401046
#
#    Rank (Pushkar Manocha)
# 0                       3
# 1                       5
# 2                       1
# 3                       2
# 4                       4
